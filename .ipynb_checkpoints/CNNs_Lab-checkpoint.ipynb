# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow_datasets as tfds
#from tensorflow.data.experimental import sample_from_datasets

tfkl = tfk.layers

# %% [markdown]
# **Preprocessing**
#
# As typical, we'll start with the MNIST data. Recall from last time, we have to do some transformations and preprocessing on these images.

# %%
data, info = tfds.load('mnist', with_info=True)

# %%
preprocess = lambda d: (tf.cast(d["image"], tf.float32)/255, tf.one_hot(d["label"], depth=10))

ds_train = data["train"].map(preprocess).cache().batch(32)
ds_test = data["test"].map(preprocess).cache().batch(32)

# %%
img_shape = info.features['image'].shape

# %%
img_shape
# Out:
# (28, 28, 1)

# %% [markdown]
# **CNNs in TF Keras**
#
# We'll use the Sequential class rely on new layer types that correspond to concepts we covered in lecture: Conv2D, AvgPool2D, MaxPool2D.
#
# Details such as kernel size, padding, strides and so on must be specified as args to these classes, where appropriate.

# %%
model = tfk.Sequential()
model.add(tfkl.Conv2D(filters = 1, kernel_size=(3,3), strides=(1,1), 
                      padding="valid", activation='relu', input_shape=(28, 28, 1)))
model.add(tfkl.MaxPool2D(pool_size=(4,4)))
model.add(tfkl.Flatten())
model.add(tfkl.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 1)         10
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 1)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 36)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                370
# =================================================================
# Total params: 380
# Trainable params: 380
# Non-trainable params: 0
# _________________________________________________________________

# %%
# (None, 26, 26, 1) the None means the dimension is variable?
# why dimensions are decreasing: using kernels, so shrinking
# flatten: 6,6,1 => 36
# 10 in the dense: 3 by 3 kernel + bias

#can adjust the filter if your model is not performing well
#filter = 1
#filter = 2 has two kernels
#filter = 32, each of them can adjust for completely different things, like color/shape/line...

#after change filter = 32:
#(None, 26, 26, 32)  320parameters
#(None, 6, 6, 32)
#(None, 1152)
#(None, 10)

# %%
model.compile(
    optimizer=tfk.optimizers.RMSprop(),
    loss=tfk.losses.CategoricalCrossentropy(),
)

results = model.fit(ds_train, steps_per_epoch=20, epochs=20, validation_data=ds_test)
# Out:
# Train for 20 steps
# Epoch 1/20
# 20/20 [==============================] - 3s 143ms/step - loss: 2.3046 - val_loss: 2.3109
# Epoch 2/20
# 20/20 [==============================] - 1s 69ms/step - loss: 2.2977 - val_loss: 2.2727
# Epoch 3/20
# 20/20 [==============================] - 1s 72ms/step - loss: 2.2529 - val_loss: 2.2423
# Epoch 4/20
# 20/20 [==============================] - 1s 61ms/step - loss: 2.2311 - val_loss: 2.2073
# Epoch 5/20
# 20/20 [==============================] - 2s 76ms/step - loss: 2.2027 - val_loss: 2.1690
# Epoch 6/20
# 20/20 [==============================] - 1s 72ms/step - loss: 2.1392 - val_loss: 2.1228
# Epoch 7/20
# 20/20 [==============================] - 1s 70ms/step - loss: 2.1140 - val_loss: 2.0738
# Epoch 8/20
# 20/20 [==============================] - 2s 78ms/step - loss: 2.0517 - val_loss: 2.0178
# Epoch 9/20
# 20/20 [==============================] - 1s 60ms/step - loss: 1.9649 - val_loss: 1.9554
# Epoch 10/20
# 20/20 [==============================] - 1s 63ms/step - loss: 1.9408 - val_loss: 1.8899
# Epoch 11/20
# 20/20 [==============================] - 2s 92ms/step - loss: 1.8914 - val_loss: 1.8219
# Epoch 12/20
# 20/20 [==============================] - 2s 91ms/step - loss: 1.7890 - val_loss: 1.7486
# Epoch 13/20
# 20/20 [==============================] - 1s 75ms/step - loss: 1.7298 - val_loss: 1.6773
# Epoch 14/20
# 20/20 [==============================] - 1s 68ms/step - loss: 1.6676 - val_loss: 1.6038
# Epoch 15/20
# 20/20 [==============================] - 1s 65ms/step - loss: 1.5622 - val_loss: 1.5316
# Epoch 16/20
# 20/20 [==============================] - 1s 64ms/step - loss: 1.4975 - val_loss: 1.4640
# Epoch 17/20
# 20/20 [==============================] - 1s 64ms/step - loss: 1.3966 - val_loss: 1.3954
# Epoch 18/20
# 20/20 [==============================] - 1s 67ms/step - loss: 1.3513 - val_loss: 1.3397
# Epoch 19/20
# 20/20 [==============================] - 1s 66ms/step - loss: 1.3200 - val_loss: 1.2772
# Epoch 20/20
# 20/20 [==============================] - 1s 63ms/step - loss: 1.2488 - val_loss: 1.2326

# %%
plt.plot(results.history["loss"])
plt.plot(results.history["val_loss"])
plt.legend(labels=["train", "val"])

# %%
plt.stem(model.predict(ds_test.take(1))[9, :])
plt.xlabel("Digit")
plt.xlabel("Probability")
# Out:
# /Users/xiaoyu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Probability')

# %% [markdown]
# Which architectural hyperparameters might we change in the above?

# %% [markdown]
# **Exercise - Deep CNN**
#
# Build and fit your own CNN model with 3 convolutional **modules**, where each one contains:
#   * kernel convolution
#     * you pick number of kernels
#     * you pick kernel shape/size
#     * you pick activation
#   * pooling
#   * dropout
#
# We'll use the Fashion MNIST dataset, a low-res collection of images of clothing.

# %%
train, test = tf.keras.datasets.fashion_mnist.load_data()

images, labels = train
images = images/255.0
images = images[:, :, :, np.newaxis]
labels = labels.astype(np.int32)

#optional - TF Datasets objects
fmnist_train_ds = tf.data.Dataset.from_tensor_slices((images, labels))
fmnist_train_ds = fmnist_train_ds.shuffle(5000).batch(32)

test_images, test_labels = train
test_images = test_images/255.0
test_images = test_images[:, :, :, np.newaxis]
test_labels = test_labels.astype(np.int32)


fmnist_test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
fmnist_test_ds = fmnist_test_ds.shuffle(5000).batch(32)

# %%
plt.imshow(images[3, :, :, :].squeeze())

# %%
# your code here
model = tfk.Sequential()
model.add(tfkl.Conv2D(filters = 32, kernel_size=2, strides=1, 
                      padding="valid", activation='relu', input_shape=(28, 28, 1)))
model.add(tfkl.MaxPool2D(pool_size=2))
model.add(tfkl.Dropout(0.2))
model.add(tfkl.Conv2D(filters = 16, kernel_size=2, strides=1, 
                      padding="valid", activation='relu'))
model.add(tfkl.MaxPool2D(pool_size=2))
model.add(tfkl.Dropout(0.2))

model.add(tfkl.Conv2D(filters = 8, kernel_size=2, strides=1, 
                      padding="valid", activation='relu'))
model.add(tfkl.MaxPool2D(pool_size=2))
model.add(tfkl.Dropout(0.2))

model.add(tfkl.GlobalMaxPool2D())
model.add(tfkl.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 27, 27, 32)        160
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 12, 12, 16)        2064
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 16)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 16)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 5, 5, 8)           520
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 2, 2, 8)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 8)           0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 8)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                90
# =================================================================
# Total params: 2,834
# Trainable params: 2,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tfk.optimizers.RMSprop(),
    loss=tfk.losses.CategoricalCrossentropy(),
)

results = model.fit(fmnist_train_ds, steps_per_epoch=20, epochs=20, validation_data=fmnist_test_ds)
# Out:
# Train for 20 steps, validate for 1875 steps
# Epoch 1/20
# 20/20 [==============================] - 13s 670ms/step - loss: 118.2099 - val_loss: 123.8240
# Epoch 2/20
# 20/20 [==============================] - 13s 658ms/step - loss: 318.5516 - val_loss: 373.3782
# Epoch 3/20
# 20/20 [==============================] - 14s 720ms/step - loss: 884.4945 - val_loss: 1005.5093
# Epoch 4/20
# 20/20 [==============================] - 14s 704ms/step - loss: 2143.3717 - val_loss: 2141.9335
# Epoch 5/20
# 20/20 [==============================] - 12s 624ms/step - loss: 3993.8282 - val_loss: 3825.3744
# Epoch 6/20
# 20/20 [==============================] - 14s 711ms/step - loss: 6344.1140 - val_loss: 6114.4189
# Epoch 7/20
# 20/20 [==============================] - 14s 706ms/step - loss: 10138.9197 - val_loss: 9148.2587
# Epoch 8/20
# 20/20 [==============================] - 13s 661ms/step - loss: 14920.0581 - val_loss: 13107.0446
# Epoch 9/20
# 20/20 [==============================] - 14s 716ms/step - loss: 20194.4806 - val_loss: 17889.4525
# Epoch 10/20
# 20/20 [==============================] - 14s 713ms/step - loss: 27809.2645 - val_loss: 23751.8992
# Epoch 11/20
# 20/20 [==============================] - 16s 792ms/step - loss: 36194.2363 - val_loss: 30697.6636
# Epoch 12/20
# 20/20 [==============================] - 15s 760ms/step - loss: 45149.7083 - val_loss: 38705.5616
# Epoch 13/20
# 20/20 [==============================] - 15s 750ms/step - loss: 54583.0908 - val_loss: 47820.5649
# Epoch 14/20
# 20/20 [==============================] - 15s 726ms/step - loss: 72127.5814 - val_loss: 58940.3685
# Epoch 15/20
# 20/20 [==============================] - 18s 900ms/step - loss: 79182.9023 - val_loss: 70222.0630
# Epoch 16/20
# 20/20 [==============================] - 17s 855ms/step - loss: 104671.7605 - val_loss: 83141.8019
# Epoch 17/20
# 20/20 [==============================] - 16s 777ms/step - loss: 112533.2641 - val_loss: 97011.1410
# Epoch 18/20
# 20/20 [==============================] - 15s 751ms/step - loss: 133583.5941 - val_loss: 112707.0792
# Epoch 19/20
# 20/20 [==============================] - 17s 832ms/step - loss: 162426.5680 - val_loss: 130222.3536
# Epoch 20/20
# 20/20 [==============================] - 19s 956ms/step - loss: 183915.1352 - val_loss: 148992.0237

# %%
plt.plot(results.history["loss"])
plt.plot(results.history["val_loss"])
plt.legend(labels=["train", "val"])

# %%
plt.stem(model.predict(fmnist_test_ds.take(1))[9, :])
plt.xlabel("Digit")
plt.xlabel("Probability")
# Out:
# /Users/xiaoyu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Probability')

# %%
# your code here
model = tfk.Sequential()
model.add(tfkl.Conv2D(filters = 3, kernel_size=(4,4), strides=(1,1), 
                      padding="valid", activation='relu', input_shape=(28, 28, 1)))
model.add(tfkl.MaxPool2D(pool_size=(2,2)))
model.add(tfkl.Flatten())
model.add(tfkl.Dense(10, activation='softmax'))

# %%
model.compile(
    optimizer=tfk.optimizers.RMSprop(),
    loss=tfk.losses.CategoricalCrossentropy(),
)

results = model.fit(fmnist_train_ds, steps_per_epoch=20, epochs=20, validation_data=fmnist_test_ds)
# Out:
# Train for 20 steps, validate for 1875 steps
# Epoch 1/20
# 20/20 [==============================] - 8s 387ms/step - loss: 110.1567 - val_loss: 112.9747
# Epoch 2/20
# 20/20 [==============================] - 9s 452ms/step - loss: 114.9369 - val_loss: 118.3791
# Epoch 3/20
# 20/20 [==============================] - 9s 459ms/step - loss: 122.5432 - val_loss: 124.1754
# Epoch 4/20
# 20/20 [==============================] - 9s 463ms/step - loss: 123.6720 - val_loss: 130.3601
# Epoch 5/20
# 20/20 [==============================] - 9s 462ms/step - loss: 131.4182 - val_loss: 137.1427
# Epoch 6/20
# 20/20 [==============================] - 9s 452ms/step - loss: 140.6530 - val_loss: 144.4217
# Epoch 7/20
# 20/20 [==============================] - 9s 453ms/step - loss: 149.7499 - val_loss: 151.8018
# Epoch 8/20
# 20/20 [==============================] - 9s 467ms/step - loss: 158.5987 - val_loss: 159.4857
# Epoch 9/20
# 20/20 [==============================] - 9s 459ms/step - loss: 162.4453 - val_loss: 166.8306
# Epoch 10/20
# 20/20 [==============================] - 9s 471ms/step - loss: 174.8198 - val_loss: 175.0819
# Epoch 11/20
# 20/20 [==============================] - 9s 455ms/step - loss: 174.9777 - val_loss: 182.6474
# Epoch 12/20
# 20/20 [==============================] - 9s 454ms/step - loss: 186.2134 - val_loss: 190.4443
# Epoch 13/20
# 20/20 [==============================] - 9s 459ms/step - loss: 196.6170 - val_loss: 198.8233
# Epoch 14/20
# 20/20 [==============================] - 9s 455ms/step - loss: 206.9080 - val_loss: 207.5777
# Epoch 15/20
# 20/20 [==============================] - 9s 462ms/step - loss: 218.2033 - val_loss: 215.6418
# Epoch 16/20
# 20/20 [==============================] - 9s 452ms/step - loss: 221.3392 - val_loss: 223.2731
# Epoch 17/20
# 20/20 [==============================] - 9s 451ms/step - loss: 237.1278 - val_loss: 231.7951
# Epoch 18/20
# 20/20 [==============================] - 10s 479ms/step - loss: 237.5519 - val_loss: 240.4316
# Epoch 19/20
# 20/20 [==============================] - 9s 461ms/step - loss: 249.6772 - val_loss: 248.9311
# Epoch 20/20
# 20/20 [==============================] - 9s 473ms/step - loss: 257.0123 - val_loss: 256.7727

# %%
plt.plot(results.history["loss"])
plt.plot(results.history["val_loss"])
plt.legend(labels=["train", "val"])

# %%
plt.stem(model.predict(fmnist_test_ds.take(1))[9, :])
plt.xlabel("Digit")
plt.xlabel("Probability")
# Out:
# /Users/xiaoyu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Probability')

# %%
# your code here
model = tfk.Sequential()
model.add(tfkl.Conv2D(filters = 32, kernel_size=(3,3), strides=(1,1), 
                      padding="valid", activation='relu', input_shape=(28, 28, 1)))
model.add(tfkl.MaxPool2D(pool_size=(2,2)))
model.add(tfkl.Flatten())
model.add(tfkl.Dense(10, activation='softmax'))

# %% [markdown]
# #|**Exercise - Transfer Learning**

# %%
data, info = tfds.load('rock_paper_scissors', with_info=True)
train_data = data["train"].map(lambda x: (tf.cast(x["image"], tf.float32) / 255., tf.one_hot(x["label"], depth=3) )).batch(32)
# Out:
# Downloading and preparing dataset rock_paper_scissors/3.0.0 (download: 219.53 MiB, generated: Unknown size, total: 219.53 MiB) to /Users/xiaoyu/tensorflow_datasets/rock_paper_scissors/3.0.0...
# HBox(children=(HTML(value='Dl Completed...'), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='…
# HBox(children=(HTML(value='Dl Size...'), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'…
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Shuffling and writing examples to /Users/xiaoyu/tensorflow_datasets/rock_paper_scissors/3.0.0.incomplete8CDCDO/rock_paper_scissors-train.tfrecord
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2520.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Shuffling and writing examples to /Users/xiaoyu/tensorflow_datasets/rock_paper_scissors/3.0.0.incomplete8CDCDO/rock_paper_scissors-test.tfrecord
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=372.0), HTML(value='')))
# Dataset rock_paper_scissors downloaded and prepared to /Users/xiaoyu/tensorflow_datasets/rock_paper_scissors/3.0.0. Subsequent calls will reuse this data.

# %%
info.features['image'].shape
# Out:
# (300, 300, 3)

# %%
tfds.as_dataframe(data["train"].take(10), info)
# Out:
#                                                image  label
# 0  [[[254, 254, 254], [253, 253, 253], [254, 254,...      2
# 1  [[[254, 254, 254], [253, 253, 253], [254, 254,...      2
# 2  [[[254, 254, 254], [253, 253, 253], [254, 254,...      0
# 3  [[[253, 253, 253], [253, 253, 253], [254, 254,...      1
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...      0
# 5  [[[255, 255, 255], [255, 255, 255], [255, 255,...      1
# 6  [[[253, 253, 253], [253, 253, 253], [254, 254,...      2
# 7  [[[255, 255, 255], [255, 255, 255], [255, 255,...      1
# 8  [[[253, 253, 253], [253, 253, 253], [255, 255,...      2
# 9  [[[253, 253, 253], [254, 254, 254], [254, 254,...      2

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Build a deep CNN model and train it for this binary classification task. Fit the model using the small dataset of 500 samples, *train_data*.
#
# What accuracy can your model acheive on the training data?

# %%
# Your code here

# %% [markdown]
#  2. Now use transfer learning by incorporating the pretrained VGG16 model.

# %%
from tensorflow.keras.applications import VGG16

# %%
conv_base = VGG16(weights="imagenet",include_top=False,input_shape=(300,300,3))

# %% [markdown]
# Build a Sequential model, using our VGG16 base. Make sure the freeze the weights of the convolutional backbone, but leave the remainder of the network weights as learnable. Fit this model and compare the overall accuracy as well as the loss curves (efficiency).

# %%
# Your code here
